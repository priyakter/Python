# %% [markdown]
# <a href="https://colab.research.google.com/github/priyakter/Python/blob/main/8_queen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

# Function to calculate the number of conflicting pairs of queens
def calculate_conflicts(board):
    conflicts = 0
    n = len(board)

    for i in range(n):
        for j in range(i + 1, n):
            # If queens are in the same row or in diagonal conflict
            if board[i] == board[j] or abs(board[i] - board[j]) == abs(i - j):
                conflicts += 1
    return conflicts

# Function to create a random board (state)
def create_random_board(n):
    return [random.randint(0, n - 1) for _ in range(n)]

# Function to perform a random move by changing the position of a queen in one column
def make_random_move(board):
    new_board = board[:]
    n = len(new_board)
    col = random.randint(0, n - 1)  # Random column
    row = random.randint(0, n - 1)  # Random row
    new_board[col] = row
    return new_board

# Simulated Annealing function
def simulated_annealing(n, initial_temp, cooling_rate, min_temp):
    current_board = create_random_board(n)
    current_conflicts = calculate_conflicts(current_board)
    temperature = initial_temp

    print(f"Initial random board: {current_board}")
    print(f"Initial conflicts: {current_conflicts}\n")

    while temperature > min_temp and current_conflicts > 0:
        # Make a random move (neighbor)
        new_board = make_random_move(current_board)
        new_conflicts = calculate_conflicts(new_board)

        # Calculate change in conflicts
        delta_conflicts = new_conflicts - current_conflicts

        # Print the current board and conflicts after each move
        print(f"Current board: {current_board}")
        print(f"Conflicts: {current_conflicts}")
        print(f"Temperature: {temperature:.2f}\n")

        # If the new board has fewer conflicts, accept it
        if delta_conflicts < 0:
            current_board = new_board
            current_conflicts = new_conflicts
        else:
            # Accept with a probability based on the temperature
            if random.uniform(0, 1) < math.exp(-delta_conflicts / temperature):
                current_board = new_board
                current_conflicts = new_conflicts

        temperature *= cooling_rate

    return current_board, current_conflicts

# Main function to solve the 8-queen problem
def solve_8_queens():
    n = 8
    initial_temp = 1000
    cooling_rate = 0.99
    min_temp = 0.01

    solution, conflicts = simulated_annealing(n, initial_temp, cooling_rate, min_temp)

    if conflicts == 0:
        print("Solution found:")
        print(solution)
    else:
        print("No solution found, conflicts remaining:", conflicts)
        print(solution)

solve_8_queens()
# Out:
# Initial random board: [7, 1, 1, 2, 7, 6, 5, 6]
# Initial conflicts: 12
#
# Current board: [7, 1, 1, 2, 7, 6, 5, 6]
# Conflicts: 12
# Temperature: 1000.00
#
# Current board: [7, 1, 7, 2, 7, 6, 5, 6]
# Conflicts: 10
# Temperature: 990.00
#
# Current board: [7, 1, 7, 2, 7, 6, 5, 6]
# Conflicts: 10
# Temperature: 980.10
#
# Current board: [7, 1, 7, 2, 7, 6, 3, 6]
# Conflicts: 7
# Temperature: 970.30
#
# Current board: [3, 1, 7, 2, 7, 6, 3, 6]
# Conflicts: 7
# Temperature: 960.60
#
# Current board: [3, 1, 7, 2, 7, 7, 3, 6]
# Conflicts: 7
# Temperature: 950.99
#
# Current board: [3, 1, 7, 2, 7, 4, 3, 6]
# Conflicts: 9
# Temperature: 941.48
#
# Current board: [3, 1, 7, 2, 7, 4, 3, 6]
# Conflicts: 9
# Temperature: 932.07
#
# Current board: [3, 1, 7, 1, 7, 4, 3, 6]
# Conflicts: 8
# Temperature: 922.74
#
# Current board: [3, 1, 7, 5, 7, 4, 3, 6]
# Conflicts: 7
# Temperature: 913.52
#
# Current board: [0, 1, 7, 5, 7, 4, 3, 6]
# Conflicts: 6
# Temperature: 904.38
#
# Current board: [0, 1, 7, 5, 7, 4, 3, 6]
# Conflicts: 6
# Temperature: 895.34
#
# Current board: [0, 1, 5, 5, 7, 4, 3, 6]
# Conflicts: 5
# Temperature: 886.38
#
# Current board: [0, 1, 5, 5, 7, 4, 3, 6]
# Conflicts: 5
# Temperature: 877.52
#
# Current board: [0, 1, 5, 5, 7, 1, 3, 6]
# Conflicts: 4
# Temperature: 868.75
#
# Current board: [0, 1, 5, 5, 7, 5, 3, 6]
# Conflicts: 7
# Temperature: 860.06
#
# Current board: [0, 4, 5, 5, 7, 5, 3, 6]
# Conflicts: 7
# Temperature: 851.46
#
# Current board: [0, 4, 5, 5, 7, 5, 3, 5]
# Conflicts: 10
# Temperature: 842.94
#
# Current board: [0, 0, 5, 5, 7, 5, 3, 5]
# Conflicts: 9
# Temperature: 834.51
#
# Current board: [0, 4, 5, 5, 7, 5, 3, 5]
# Conflicts: 10
# Temperature: 826.17
#
# Current board: [0, 3, 5, 5, 7, 5, 3, 5]
# Conflicts: 10
# Temperature: 817.91
#
# Current board: [0, 3, 2, 5, 7, 5, 3, 5]
# Conflicts: 9
# Temperature: 809.73
#
# Current board: [0, 3, 2, 2, 7, 5, 3, 5]
# Conflicts: 7
# Temperature: 801.63
#
# Current board: [0, 3, 2, 2, 7, 5, 4, 5]
# Conflicts: 8
# Temperature: 793.61
#
# Current board: [0, 0, 2, 2, 7, 5, 4, 5]
# Conflicts: 9
# Temperature: 785.68
#
# Current board: [0, 0, 2, 0, 7, 5, 4, 5]
# Conflicts: 9
# Temperature: 777.82
#
# Current board: [0, 0, 2, 4, 7, 5, 4, 5]
# Conflicts: 8
# Temperature: 770.04
#
# Current board: [0, 1, 2, 4, 7, 5, 4, 5]
# Conflicts: 10
# Temperature: 762.34
#
# Current board: [0, 1, 2, 4, 7, 5, 4, 5]
# Conflicts: 10
# Temperature: 754.72
#
# Current board: [0, 1, 1, 4, 7, 5, 4, 5]
# Conflicts: 8
# Temperature: 747.17
#
# Current board: [0, 1, 1, 4, 7, 5, 5, 5]
# Conflicts: 9
# Temperature: 739.70
#
# Current board: [0, 1, 1, 4, 7, 5, 5, 4]
# Conflicts: 10
# Temperature: 732.30
#
# Current board: [6, 1, 1, 4, 7, 5, 5, 4]
# Conflicts: 8
# Temperature: 724.98
#
# Current board: [6, 1, 1, 4, 7, 5, 6, 4]
# Conflicts: 7
# Temperature: 717.73
#
# Current board: [2, 1, 1, 4, 7, 5, 6, 4]
# Conflicts: 7
# Temperature: 710.55
#
# Current board: [2, 1, 1, 4, 7, 5, 6, 2]
# Conflicts: 6
# Temperature: 703.45
#
# Current board: [3, 1, 1, 4, 7, 5, 6, 2]
# Conflicts: 6
# Temperature: 696.41
#
# Current board: [3, 1, 1, 2, 7, 5, 6, 2]
# Conflicts: 8
# Temperature: 689.45
#
# Current board: [3, 1, 1, 2, 7, 5, 6, 2]
# Conflicts: 8
# Temperature: 682.55
#
# Current board: [3, 5, 1, 2, 7, 5, 6, 2]
# Conflicts: 6
# Temperature: 675.73
#
# Current board: [3, 5, 1, 2, 7, 5, 6, 2]
# Conflicts: 6
# Temperature: 668.97
#
# Current board: [3, 5, 1, 2, 7, 5, 6, 0]
# Conflicts: 5
# Temperature: 662.28
#
# Current board: [3, 5, 1, 0, 7, 5, 6, 0]
# Conflicts: 7
# Temperature: 655.66
#
# Current board: [3, 5, 1, 0, 7, 5, 4, 0]
# Conflicts: 7
# Temperature: 649.10
#
# Current board: [3, 5, 5, 0, 7, 5, 4, 0]
# Conflicts: 10
# Temperature: 642.61
#
# Current board: [4, 5, 5, 0, 7, 5, 4, 0]
# Conflicts: 9
# Temperature: 636.19
#
# Current board: [4, 5, 4, 0, 7, 5, 4, 0]
# Conflicts: 8
# Temperature: 629.82
#
# Current board: [4, 5, 4, 0, 7, 5, 4, 0]
# Conflicts: 8
# Temperature: 623.53
#
# Current board: [4, 5, 7, 0, 7, 5, 4, 0]
# Conflicts: 6
# Temperature: 617.29
#
# Current board: [4, 5, 4, 0, 7, 5, 4, 0]
# Conflicts: 8
# Temperature: 611.12
#
# Current board: [4, 5, 7, 0, 7, 5, 4, 0]
# Conflicts: 6
# Temperature: 605.01
#
# Current board: [4, 5, 7, 0, 7, 5, 6, 0]
# Conflicts: 5
# Temperature: 598.96
#
# Current board: [4, 5, 7, 1, 7, 5, 6, 0]
# Conflicts: 5
# Temperature: 592.97
#
# Current board: [4, 5, 7, 6, 7, 5, 6, 0]
# Conflicts: 7
# Temperature: 587.04
#
# Current board: [0, 5, 7, 6, 7, 5, 6, 0]
# Conflicts: 9
# Temperature: 581.17
#
# Current board: [0, 5, 7, 0, 7, 5, 6, 0]
# Conflicts: 8
# Temperature: 575.35
#
# Current board: [0, 5, 7, 0, 7, 5, 1, 0]
# Conflicts: 7
# Temperature: 569.60
#
# Current board: [0, 5, 1, 0, 7, 5, 1, 0]
# Conflicts: 8
# Temperature: 563.91
#
# Current board: [0, 5, 1, 0, 7, 0, 1, 0]
# Conflicts: 10
# Temperature: 558.27
#
# Current board: [4, 5, 1, 0, 7, 0, 1, 0]
# Conflicts: 8
# Temperature: 552.68
#
# Current board: [4, 5, 1, 0, 7, 0, 1, 0]
# Conflicts: 8
# Temperature: 547.16
#
# Current board: [4, 5, 1, 0, 7, 0, 5, 0]
# Conflicts: 8
# Temperature: 541.69
#
# Current board: [4, 4, 1, 0, 7, 0, 5, 0]
# Conflicts: 9
# Temperature: 536.27
#
# Current board: [4, 4, 1, 0, 7, 0, 5, 0]
# Conflicts: 9
# Temperature: 530.91
#
# Current board: [4, 4, 1, 0, 7, 0, 5, 0]
# Conflicts: 9
# Temperature: 525.60
#
# Current board: [4, 4, 1, 0, 7, 0, 5, 0]
# Conflicts: 9
# Temperature: 520.34
#
# Current board: [4, 4, 1, 0, 7, 0, 2, 0]
# Conflicts: 7
# Temperature: 515.14
#
# Current board: [4, 4, 1, 6, 7, 0, 2, 0]
# Conflicts: 6
# Temperature: 509.99
#
# Current board: [4, 4, 1, 3, 7, 0, 2, 0]
# Conflicts: 4
# Temperature: 504.89
#
# Current board: [4, 4, 1, 3, 6, 0, 2, 0]
# Conflicts: 3
# Temperature: 499.84
#
# Current board: [4, 4, 1, 3, 6, 0, 0, 0]
# Conflicts: 6
# Temperature: 494.84
#
# Current board: [4, 1, 1, 3, 6, 0, 0, 0]
# Conflicts: 6
# Temperature: 489.89
#
# Current board: [4, 1, 1, 3, 2, 0, 0, 0]
# Conflicts: 8
# Temperature: 484.99
#
# Current board: [4, 1, 1, 3, 2, 0, 0, 7]
# Conflicts: 8
# Temperature: 480.14
#
# Current board: [2, 1, 1, 3, 2, 0, 0, 7]
# Conflicts: 10
# Temperature: 475.34
#
# Current board: [2, 1, 1, 3, 2, 2, 0, 7]
# Conflicts: 11
# Temperature: 470.59
#
# Current board: [2, 1, 1, 3, 2, 2, 0, 7]
# Conflicts: 11
# Temperature: 465.88
#
# Current board: [2, 1, 1, 3, 2, 2, 0, 2]
# Conflicts: 12
# Temperature: 461.22
#
# Current board: [2, 0, 1, 3, 2, 2, 0, 2]
# Conflicts: 11
# Temperature: 456.61
#
# Current board: [2, 0, 1, 3, 2, 4, 0, 2]
# Conflicts: 11
# Temperature: 452.04
#
# Current board: [3, 0, 1, 3, 2, 4, 0, 2]
# Conflicts: 11
# Temperature: 447.52
#
# Current board: [3, 0, 1, 3, 2, 4, 0, 3]
# Conflicts: 11
# Temperature: 443.05
#
# Current board: [3, 2, 1, 3, 2, 4, 0, 3]
# Conflicts: 11
# Temperature: 438.62
#
# Current board: [3, 2, 3, 3, 2, 4, 0, 3]
# Conflicts: 12
# Temperature: 434.23
#
# Current board: [3, 2, 6, 3, 2, 4, 0, 3]
# Conflicts: 8
# Temperature: 429.89
#
# Current board: [5, 2, 6, 3, 2, 4, 0, 3]
# Conflicts: 5
# Temperature: 425.59
#
# Current board: [5, 2, 6, 3, 2, 4, 0, 7]
# Conflicts: 5
# Temperature: 421.33
#
# Current board: [5, 2, 6, 3, 2, 4, 0, 1]
# Conflicts: 6
# Temperature: 417.12
#
# Current board: [4, 2, 6, 3, 2, 4, 0, 1]
# Conflicts: 8
# Temperature: 412.95
#
# Current board: [4, 2, 6, 3, 6, 4, 0, 1]
# Conflicts: 6
# Temperature: 408.82
#
# Current board: [3, 2, 6, 3, 6, 4, 0, 1]
# Conflicts: 6
# Temperature: 404.73
#
# Current board: [3, 2, 6, 3, 6, 4, 7, 1]
# Conflicts: 5
# Temperature: 400.68
#
# Current board: [3, 2, 6, 7, 6, 4, 7, 1]
# Conflicts: 7
# Temperature: 396.68
#
# Current board: [3, 2, 6, 7, 6, 0, 7, 1]
# Conflicts: 7
# Temperature: 392.71
#
# Current board: [3, 2, 3, 7, 6, 0, 7, 1]
# Conflicts: 8
# Temperature: 388.78
#
# Current board: [3, 2, 3, 7, 6, 0, 6, 1]
# Conflicts: 6
# Temperature: 384.90
#
# Current board: [3, 2, 3, 7, 6, 0, 1, 1]
# Conflicts: 7
# Temperature: 381.05
#
# Current board: [3, 2, 3, 7, 6, 0, 1, 1]
# Conflicts: 7
# Temperature: 377.24
#
# Current board: [3, 2, 3, 7, 5, 0, 1, 1]
# Conflicts: 8
# Temperature: 373.46
#
# Current board: [3, 2, 3, 2, 5, 0, 1, 1]
# Conflicts: 11
# Temperature: 369.73
#
# Current board: [3, 5, 3, 2, 5, 0, 1, 1]
# Conflicts: 8
# Temperature: 366.03
#
# Current board: [0, 5, 3, 2, 5, 0, 1, 1]
# Conflicts: 8
# Temperature: 362.37
#
# Current board: [0, 5, 7, 2, 5, 0, 1, 1]
# Conflicts: 6
# Temperature: 358.75
#
# Current board: [0, 5, 7, 2, 7, 0, 1, 1]
# Conflicts: 5
# Temperature: 355.16
#
# Current board: [0, 5, 7, 0, 7, 0, 1, 1]
# Conflicts: 6
# Temperature: 351.61
#
# Current board: [0, 2, 7, 0, 7, 0, 1, 1]
# Conflicts: 7
# Temperature: 348.09
#
# Current board: [0, 2, 7, 0, 7, 0, 1, 0]
# Conflicts: 10
# Temperature: 344.61
#
# Current board: [0, 2, 2, 0, 7, 0, 1, 0]
# Conflicts: 11
# Temperature: 341.17
#
# Current board: [0, 2, 2, 0, 7, 3, 1, 0]
# Conflicts: 7
# Temperature: 337.75
#
# Current board: [0, 2, 1, 0, 7, 3, 1, 0]
# Conflicts: 8
# Temperature: 334.38
#
# Current board: [0, 2, 1, 0, 7, 3, 1, 0]
# Conflicts: 8
# Temperature: 331.03
#
# Current board: [0, 2, 1, 5, 7, 3, 1, 0]
# Conflicts: 5
# Temperature: 327.72
#
# Current board: [0, 2, 1, 5, 7, 0, 1, 0]
# Conflicts: 7
# Temperature: 324.45
#
# Current board: [0, 2, 1, 5, 7, 0, 7, 0]
# Conflicts: 6
# Temperature: 321.20
#
# Current board: [0, 2, 0, 5, 7, 0, 7, 0]
# Conflicts: 8
# Temperature: 317.99
#
# Current board: [0, 2, 0, 3, 7, 0, 7, 0]
# Conflicts: 9
# Temperature: 314.81
#
# Current board: [0, 2, 0, 3, 7, 0, 5, 0]
# Conflicts: 8
# Temperature: 311.66
#
# Current board: [2, 2, 0, 3, 7, 0, 5, 0]
# Conflicts: 6
# Temperature: 308.54
#
# Current board: [2, 1, 0, 3, 7, 0, 5, 0]
# Conflicts: 8
# Temperature: 305.46
#
# Current board: [2, 1, 0, 0, 7, 0, 5, 0]
# Conflicts: 10
# Temperature: 302.40
#
# Current board: [2, 1, 0, 0, 0, 0, 5, 0]
# Conflicts: 13
# Temperature: 299.38
#
# Current board: [2, 1, 0, 0, 5, 0, 5, 0]
# Conflicts: 10
# Temperature: 296.39
#
# Current board: [2, 1, 0, 0, 4, 0, 5, 0]
# Conflicts: 10
# Temperature: 293.42
#
# Current board: [2, 1, 0, 0, 4, 0, 5, 1]
# Conflicts: 9
# Temperature: 290.49
#
# Current board: [2, 1, 0, 0, 4, 5, 5, 1]
# Conflicts: 10
# Temperature: 287.58
#
# Current board: [2, 2, 0, 0, 4, 5, 5, 1]
# Conflicts: 7
# Temperature: 284.71
#
# Current board: [2, 2, 0, 0, 4, 1, 5, 1]
# Conflicts: 6
# Temperature: 281.86
#
# Current board: [3, 2, 0, 0, 4, 1, 5, 1]
# Conflicts: 6
# Temperature: 279.04
#
# Current board: [3, 2, 0, 6, 4, 1, 5, 1]
# Conflicts: 4
# Temperature: 276.25
#
# Current board: [0, 2, 0, 6, 4, 1, 5, 1]
# Conflicts: 4
# Temperature: 273.49
#
# Current board: [0, 0, 0, 6, 4, 1, 5, 1]
# Conflicts: 7
# Temperature: 270.75
#
# Current board: [0, 0, 0, 6, 4, 4, 5, 1]
# Conflicts: 10
# Temperature: 268.05
#
# Current board: [0, 0, 0, 6, 4, 4, 5, 0]
# Conflicts: 12
# Temperature: 265.37
#
# Current board: [0, 0, 0, 4, 4, 4, 5, 0]
# Conflicts: 14
# Temperature: 262.71
#
# Current board: [0, 0, 4, 4, 4, 4, 5, 0]
# Conflicts: 14
# Temperature: 260.09
#
# Current board: [0, 0, 4, 4, 4, 4, 4, 0]
# Conflicts: 16
# Temperature: 257.48
#
# Current board: [0, 1, 4, 4, 4, 4, 4, 0]
# Conflicts: 15
# Temperature: 254.91
#
# Current board: [0, 1, 4, 4, 4, 4, 4, 0]
# Conflicts: 15
# Temperature: 252.36
#
# Current board: [0, 1, 4, 4, 4, 4, 4, 6]
# Conflicts: 14
# Temperature: 249.84
#
# Current board: [0, 1, 4, 4, 4, 4, 4, 6]
# Conflicts: 14
# Temperature: 247.34
#
# Current board: [0, 1, 4, 6, 4, 4, 4, 6]
# Conflicts: 12
# Temperature: 244.87
#
# Current board: [0, 1, 4, 6, 4, 4, 4, 3]
# Conflicts: 11
# Temperature: 242.42
#
# Current board: [0, 1, 4, 6, 3, 4, 4, 3]
# Conflicts: 8
# Temperature: 239.99
#
# Current board: [0, 2, 4, 6, 3, 4, 4, 3]
# Conflicts: 7
# Temperature: 237.59
#
# Current board: [0, 2, 4, 6, 3, 4, 3, 3]
# Conflicts: 8
# Temperature: 235.22
#
# Current board: [0, 2, 4, 6, 3, 4, 3, 3]
# Conflicts: 8
# Temperature: 232.86
#
# Current board: [0, 2, 4, 6, 3, 0, 3, 3]
# Conflicts: 5
# Temperature: 230.54
#
# Current board: [0, 2, 4, 6, 1, 0, 3, 3]
# Conflicts: 5
# Temperature: 228.23
#
# Current board: [0, 2, 4, 6, 1, 0, 3, 3]
# Conflicts: 5
# Temperature: 225.95
#
# Current board: [0, 2, 4, 6, 1, 0, 3, 1]
# Conflicts: 5
# Temperature: 223.69
#
# Current board: [0, 2, 4, 6, 1, 0, 6, 1]
# Conflicts: 5
# Temperature: 221.45
#
# Current board: [4, 2, 4, 6, 1, 0, 6, 1]
# Conflicts: 4
# Temperature: 219.24
#
# Current board: [4, 3, 4, 6, 1, 0, 6, 1]
# Conflicts: 6
# Temperature: 217.04
#
# Current board: [4, 3, 4, 7, 1, 0, 6, 1]
# Conflicts: 6
# Temperature: 214.87
#
# Current board: [5, 3, 4, 7, 1, 0, 6, 1]
# Conflicts: 5
# Temperature: 212.73
#
# Current board: [5, 3, 3, 7, 1, 0, 6, 1]
# Conflicts: 8
# Temperature: 210.60
#
# Current board: [5, 3, 3, 7, 6, 0, 6, 1]
# Conflicts: 7
# Temperature: 208.49
#
# Current board: [5, 3, 3, 1, 6, 0, 6, 1]
# Conflicts: 8
# Temperature: 206.41
#
# Current board: [5, 3, 3, 1, 7, 0, 6, 1]
# Conflicts: 6
# Temperature: 204.34
#
# Current board: [5, 3, 3, 5, 7, 0, 6, 1]
# Conflicts: 7
# Temperature: 202.30
#
# Current board: [5, 6, 3, 5, 7, 0, 6, 1]
# Conflicts: 7
# Temperature: 200.28
#
# Current board: [5, 6, 3, 5, 7, 0, 6, 1]
# Conflicts: 7
# Temperature: 198.27
#
# Current board: [5, 7, 3, 5, 7, 0, 6, 1]
# Conflicts: 8
# Temperature: 196.29
#
# Current board: [5, 1, 3, 5, 7, 0, 6, 1]
# Conflicts: 7
# Temperature: 194.33
#
# Current board: [5, 1, 3, 5, 7, 1, 6, 1]
# Conflicts: 7
# Temperature: 192.39
#
# Current board: [5, 1, 4, 5, 7, 1, 6, 1]
# Conflicts: 8
# Temperature: 190.46
#
# Current board: [5, 1, 3, 5, 7, 1, 6, 1]
# Conflicts: 7
# Temperature: 188.56
#
# Current board: [5, 1, 3, 5, 7, 1, 6, 5]
# Conflicts: 7
# Temperature: 186.67
#
# Current board: [5, 5, 3, 5, 7, 1, 6, 5]
# Conflicts: 9
# Temperature: 184.80
#
# Current board: [5, 5, 3, 5, 7, 1, 6, 4]
# Conflicts: 6
# Temperature: 182.96
#
# Current board: [5, 5, 3, 5, 7, 1, 6, 4]
# Conflicts: 6
# Temperature: 181.13
#
# Current board: [5, 5, 3, 5, 1, 1, 6, 4]
# Conflicts: 9
# Temperature: 179.32
#
# Current board: [3, 5, 3, 5, 1, 1, 6, 4]
# Conflicts: 6
# Temperature: 177.52
#
# Current board: [3, 5, 3, 5, 1, 1, 0, 4]
# Conflicts: 8
# Temperature: 175.75
#
# Current board: [3, 5, 3, 5, 1, 1, 0, 4]
# Conflicts: 8
# Temperature: 173.99
#
# Current board: [3, 5, 3, 5, 6, 1, 0, 4]
# Conflicts: 6
# Temperature: 172.25
#
# Current board: [3, 5, 3, 5, 6, 6, 0, 4]
# Conflicts: 7
# Temperature: 170.53
#
# Current board: [3, 5, 3, 5, 0, 6, 0, 4]
# Conflicts: 6
# Temperature: 168.82
#
# Current board: [0, 5, 3, 5, 0, 6, 0, 4]
# Conflicts: 7
# Temperature: 167.13
#
# Current board: [0, 5, 3, 5, 0, 4, 0, 4]
# Conflicts: 6
# Temperature: 165.46
#
# Current board: [0, 5, 4, 5, 0, 4, 0, 4]
# Conflicts: 11
# Temperature: 163.81
#
# Current board: [0, 5, 4, 5, 0, 2, 0, 4]
# Conflicts: 10
# Temperature: 162.17
#
# Current board: [0, 5, 4, 5, 0, 2, 0, 5]
# Conflicts: 10
# Temperature: 160.55
#
# Current board: [0, 1, 4, 5, 0, 2, 0, 5]
# Conflicts: 7
# Temperature: 158.94
#
# Current board: [0, 1, 4, 5, 0, 2, 0, 5]
# Conflicts: 7
# Temperature: 157.35
#
# Current board: [0, 2, 4, 5, 0, 2, 0, 5]
# Conflicts: 7
# Temperature: 155.78
#
# Current board: [0, 2, 4, 4, 0, 2, 0, 5]
# Conflicts: 8
# Temperature: 154.22
#
# Current board: [0, 2, 4, 4, 5, 2, 0, 5]
# Conflicts: 9
# Temperature: 152.68
#
# Current board: [0, 2, 4, 4, 5, 2, 0, 6]
# Conflicts: 8
# Temperature: 151.15
#
# Current board: [0, 2, 0, 4, 5, 2, 0, 6]
# Conflicts: 8
# Temperature: 149.64
#
# Current board: [0, 2, 0, 4, 5, 2, 7, 6]
# Conflicts: 10
# Temperature: 148.14
#
# Current board: [2, 2, 0, 4, 5, 2, 7, 6]
# Conflicts: 12
# Temperature: 146.66
#
# Current board: [2, 2, 0, 4, 5, 2, 7, 6]
# Conflicts: 12
# Temperature: 145.20
#
# Current board: [2, 2, 0, 4, 5, 2, 7, 0]
# Conflicts: 14
# Temperature: 143.74
#
# Current board: [2, 2, 1, 4, 5, 2, 7, 0]
# Conflicts: 13
# Temperature: 142.31
#
# Current board: [2, 2, 7, 4, 5, 2, 7, 0]
# Conflicts: 14
# Temperature: 140.88
#
# Current board: [2, 2, 7, 5, 5, 2, 7, 0]
# Conflicts: 11
# Temperature: 139.48
#
# Current board: [4, 2, 7, 5, 5, 2, 7, 0]
# Conflicts: 8
# Temperature: 138.08
#
# Current board: [4, 2, 7, 5, 5, 4, 7, 0]
# Conflicts: 9
# Temperature: 136.70
#
# Current board: [4, 2, 7, 5, 7, 4, 7, 0]
# Conflicts: 6
# Temperature: 135.33
#
# Current board: [4, 2, 7, 5, 7, 4, 2, 0]
# Conflicts: 5
# Temperature: 133.98
#
# Current board: [4, 2, 7, 5, 7, 4, 2, 3]
# Conflicts: 6
# Temperature: 132.64
#
# Current board: [1, 2, 7, 5, 7, 4, 2, 3]
# Conflicts: 6
# Temperature: 131.31
#
# Current board: [1, 2, 7, 5, 7, 4, 2, 7]
# Conflicts: 7
# Temperature: 130.00
#
# Current board: [1, 2, 7, 5, 5, 4, 2, 7]
# Conflicts: 10
# Temperature: 128.70
#
# Current board: [1, 2, 7, 5, 5, 5, 2, 7]
# Conflicts: 11
# Temperature: 127.41
#
# Current board: [1, 2, 7, 5, 5, 5, 1, 7]
# Conflicts: 10
# Temperature: 126.14
#
# Current board: [4, 2, 7, 5, 5, 5, 1, 7]
# Conflicts: 7
# Temperature: 124.88
#
# Current board: [4, 2, 7, 5, 5, 3, 1, 7]
# Conflicts: 5
# Temperature: 123.63
#
# Current board: [4, 2, 7, 5, 6, 3, 1, 7]
# Conflicts: 3
# Temperature: 122.39
#
# Current board: [4, 2, 7, 5, 6, 3, 1, 7]
# Conflicts: 3
# Temperature: 121.17
#
# Current board: [4, 2, 7, 5, 6, 3, 5, 7]
# Conflicts: 4
# Temperature: 119.96
#
# Current board: [4, 2, 7, 5, 6, 3, 5, 4]
# Conflicts: 5
# Temperature: 118.76
#
# Current board: [4, 2, 7, 7, 6, 3, 5, 4]
# Conflicts: 5
# Temperature: 117.57
#
# Current board: [4, 2, 7, 7, 6, 3, 7, 4]
# Conflicts: 7
# Temperature: 116.39
#
# Current board: [4, 2, 7, 7, 6, 3, 7, 3]
# Conflicts: 9
# Temperature: 115.23
#
# Current board: [4, 2, 7, 7, 6, 3, 7, 5]
# Conflicts: 7
# Temperature: 114.08
#
# Current board: [4, 2, 7, 7, 6, 3, 7, 0]
# Conflicts: 6
# Temperature: 112.94
#
# Current board: [4, 2, 7, 7, 6, 3, 7, 0]
# Conflicts: 6
# Temperature: 111.81
#
# Current board: [4, 2, 7, 6, 6, 3, 7, 0]
# Conflicts: 4
# Temperature: 110.69
#
# Current board: [4, 2, 0, 6, 6, 3, 7, 0]
# Conflicts: 4
# Temperature: 109.58
#
# Current board: [4, 2, 0, 6, 6, 4, 7, 0]
# Conflicts: 5
# Temperature: 108.49
#
# Current board: [4, 7, 0, 6, 6, 4, 7, 0]
# Conflicts: 5
# Temperature: 107.40
#
# Current board: [4, 7, 0, 6, 6, 4, 7, 0]
# Conflicts: 5
# Temperature: 106.33
#
# Current board: [4, 7, 0, 6, 6, 4, 7, 5]
# Conflicts: 5
# Temperature: 105.26
#
# Current board: [4, 7, 0, 6, 6, 4, 7, 5]
# Conflicts: 5
# Temperature: 104.21
#
# Current board: [4, 7, 0, 6, 4, 4, 7, 5]
# Conflicts: 7
# Temperature: 103.17
#
# Current board: [4, 7, 0, 6, 4, 4, 7, 5]
# Conflicts: 7
# Temperature: 102.14
#
# Current board: [4, 7, 0, 2, 4, 4, 7, 5]
# Conflicts: 7
# Temperature: 101.12
#
# Current board: [4, 7, 0, 2, 6, 4, 7, 5]
# Conflicts: 4
# Temperature: 100.11
#
# Current board: [4, 7, 0, 7, 6, 4, 7, 5]
# Conflicts: 7
# Temperature: 99.10
#
# Current board: [4, 7, 0, 7, 6, 6, 7, 5]
# Conflicts: 8
# Temperature: 98.11
#
# Current board: [4, 4, 0, 7, 6, 6, 7, 5]
# Conflicts: 7
# Temperature: 97.13
#
# Current board: [4, 4, 4, 7, 6, 6, 7, 5]
# Conflicts: 9
# Temperature: 96.16
#
# Current board: [4, 4, 4, 7, 6, 6, 7, 5]
# Conflicts: 9
# Temperature: 95.20
#
# Current board: [4, 4, 4, 7, 6, 6, 7, 5]
# Conflicts: 9
# Temperature: 94.25
#
# Current board: [4, 4, 4, 7, 3, 6, 7, 5]
# Conflicts: 6
# Temperature: 93.31
#
# Current board: [4, 4, 4, 7, 3, 6, 7, 5]
# Conflicts: 6
# Temperature: 92.37
#
# Current board: [4, 4, 5, 7, 3, 6, 7, 5]
# Conflicts: 7
# Temperature: 91.45
#
# Current board: [4, 4, 5, 7, 3, 6, 1, 5]
# Conflicts: 7
# Temperature: 90.53
#
# Current board: [4, 4, 5, 7, 2, 6, 1, 5]
# Conflicts: 6
# Temperature: 89.63
#
# Current board: [4, 4, 3, 7, 2, 6, 1, 5]
# Conflicts: 5
# Temperature: 88.73
#
# Current board: [4, 4, 3, 7, 2, 6, 1, 1]
# Conflicts: 5
# Temperature: 87.85
#
# Current board: [4, 4, 3, 0, 2, 6, 1, 1]
# Conflicts: 4
# Temperature: 86.97
#
# Current board: [4, 4, 3, 0, 2, 6, 5, 1]
# Conflicts: 4
# Temperature: 86.10
#
# Current board: [6, 4, 3, 0, 2, 6, 5, 1]
# Conflicts: 5
# Temperature: 85.24
#
# Current board: [6, 4, 3, 0, 2, 6, 5, 1]
# Conflicts: 5
# Temperature: 84.38
#
# Current board: [6, 4, 2, 0, 2, 6, 5, 1]
# Conflicts: 4
# Temperature: 83.54
#
# Current board: [7, 4, 2, 0, 2, 6, 5, 1]
# Conflicts: 2
# Temperature: 82.70
#
# Current board: [7, 1, 2, 0, 2, 6, 5, 1]
# Conflicts: 4
# Temperature: 81.88
#
# Current board: [7, 1, 2, 0, 2, 6, 5, 3]
# Conflicts: 3
# Temperature: 81.06
#
# Current board: [7, 1, 2, 0, 0, 6, 5, 3]
# Conflicts: 5
# Temperature: 80.25
#
# Current board: [7, 1, 3, 0, 0, 6, 5, 3]
# Conflicts: 5
# Temperature: 79.45
#
# Current board: [4, 1, 3, 0, 0, 6, 5, 3]
# Conflicts: 6
# Temperature: 78.65
#
# Current board: [4, 6, 3, 0, 0, 6, 5, 3]
# Conflicts: 7
# Temperature: 77.86
#
# Current board: [4, 6, 3, 0, 3, 6, 5, 3]
# Conflicts: 8
# Temperature: 77.09
#
# Current board: [4, 6, 3, 0, 3, 6, 5, 3]
# Conflicts: 8
# Temperature: 76.31
#
# Current board: [4, 3, 3, 0, 3, 6, 5, 3]
# Conflicts: 10
# Temperature: 75.55
#
# Current board: [4, 3, 3, 0, 3, 6, 5, 3]
# Conflicts: 10
# Temperature: 74.80
#
# Current board: [0, 3, 3, 0, 3, 6, 5, 3]
# Conflicts: 10
# Temperature: 74.05
#
# Current board: [0, 3, 3, 0, 0, 6, 5, 3]
# Conflicts: 10
# Temperature: 73.31
#
# Current board: [0, 3, 3, 0, 0, 6, 5, 6]
# Conflicts: 9
# Temperature: 72.57
#
# Current board: [0, 6, 3, 0, 0, 6, 5, 6]
# Conflicts: 9
# Temperature: 71.85
#
# Current board: [0, 6, 3, 0, 0, 6, 5, 1]
# Conflicts: 6
# Temperature: 71.13
#
# Current board: [0, 6, 3, 0, 4, 6, 5, 1]
# Conflicts: 6
# Temperature: 70.42
#
# Current board: [0, 6, 3, 0, 4, 2, 5, 1]
# Conflicts: 5
# Temperature: 69.72
#
# Current board: [0, 6, 3, 0, 4, 2, 5, 4]
# Conflicts: 8
# Temperature: 69.02
#
# Current board: [0, 6, 3, 0, 4, 2, 5, 4]
# Conflicts: 8
# Temperature: 68.33
#
# Current board: [0, 6, 3, 5, 4, 2, 5, 4]
# Conflicts: 7
# Temperature: 67.64
#
# Current board: [0, 6, 3, 5, 4, 1, 5, 4]
# Conflicts: 5
# Temperature: 66.97
#
# Current board: [7, 6, 3, 5, 4, 1, 5, 4]
# Conflicts: 5
# Temperature: 66.30
#
# Current board: [7, 2, 3, 5, 4, 1, 5, 4]
# Conflicts: 5
# Temperature: 65.64
#
# Current board: [7, 2, 3, 5, 6, 1, 5, 4]
# Conflicts: 4
# Temperature: 64.98
#
# Current board: [7, 2, 3, 5, 6, 1, 5, 4]
# Conflicts: 4
# Temperature: 64.33
#
# Current board: [7, 2, 3, 5, 6, 1, 5, 0]
# Conflicts: 4
# Temperature: 63.69
#
# Current board: [7, 6, 3, 5, 6, 1, 5, 0]
# Conflicts: 6
# Temperature: 63.05
#
# Current board: [7, 6, 3, 5, 6, 4, 5, 0]
# Conflicts: 7
# Temperature: 62.42
#
# Current board: [7, 4, 3, 5, 6, 4, 5, 0]
# Conflicts: 6
# Temperature: 61.79
#
# Current board: [7, 4, 4, 5, 6, 4, 5, 0]
# Conflicts: 9
# Temperature: 61.18
#
# Current board: [7, 4, 4, 5, 4, 4, 5, 0]
# Conflicts: 11
# Temperature: 60.56
#
# Current board: [0, 4, 4, 5, 4, 4, 5, 0]
# Conflicts: 12
# Temperature: 59.96
#
# Current board: [0, 2, 4, 5, 4, 4, 5, 0]
# Conflicts: 9
# Temperature: 59.36
#
# Current board: [2, 2, 4, 5, 4, 4, 5, 0]
# Conflicts: 10
# Temperature: 58.77
#
# Current board: [2, 2, 4, 5, 4, 4, 5, 5]
# Conflicts: 12
# Temperature: 58.18
#
# Current board: [2, 2, 4, 5, 5, 4, 5, 5]
# Conflicts: 14
# Temperature: 57.60
#
# Current board: [2, 2, 4, 5, 5, 4, 5, 5]
# Conflicts: 14
# Temperature: 57.02
#
# Current board: [2, 2, 4, 5, 5, 6, 5, 5]
# Conflicts: 14
# Temperature: 56.45
#
# Current board: [2, 2, 3, 5, 5, 6, 5, 5]
# Conflicts: 15
# Temperature: 55.89
#
# Current board: [2, 2, 3, 5, 5, 6, 5, 5]
# Conflicts: 15
# Temperature: 55.33
#
# Current board: [2, 2, 3, 7, 5, 6, 5, 5]
# Conflicts: 11
# Temperature: 54.77
#
# Current board: [2, 2, 3, 7, 5, 6, 7, 5]
# Conflicts: 13
# Temperature: 54.23
#
# Current board: [2, 2, 7, 7, 5, 6, 7, 5]
# Conflicts: 12
# Temperature: 53.68
#
# Current board: [2, 2, 7, 7, 5, 6, 7, 5]
# Conflicts: 12
# Temperature: 53.15
#
# Current board: [2, 2, 7, 7, 5, 6, 5, 5]
# Conflicts: 10
# Temperature: 52.62
#
# Current board: [2, 2, 7, 7, 5, 1, 5, 5]
# Conflicts: 7
# Temperature: 52.09
#
# Current board: [2, 2, 7, 7, 5, 1, 0, 5]
# Conflicts: 6
# Temperature: 51.57
#
# Current board: [2, 2, 7, 7, 5, 1, 5, 5]
# Conflicts: 7
# Temperature: 51.05
#
# Current board: [2, 2, 7, 7, 5, 1, 6, 5]
# Conflicts: 6
# Temperature: 50.54
#
# Current board: [2, 2, 7, 7, 5, 7, 6, 5]
# Conflicts: 11
# Temperature: 50.04
#
# Current board: [2, 2, 7, 0, 5, 7, 6, 5]
# Conflicts: 10
# Temperature: 49.54
#
# Current board: [2, 2, 7, 0, 5, 7, 6, 5]
# Conflicts: 10
# Temperature: 49.04
#
# Current board: [2, 2, 7, 0, 5, 7, 6, 6]
# Conflicts: 8
# Temperature: 48.55
#
# Current board: [2, 2, 7, 5, 5, 7, 6, 6]
# Conflicts: 10
# Temperature: 48.06
#
# Current board: [2, 0, 7, 5, 5, 7, 6, 6]
# Conflicts: 9
# Temperature: 47.58
#
# Current board: [2, 0, 3, 5, 5, 7, 6, 6]
# Conflicts: 8
# Temperature: 47.11
#
# Current board: [2, 0, 3, 5, 5, 7, 6, 6]
# Conflicts: 8
# Temperature: 46.64
#
# Current board: [2, 0, 3, 5, 5, 7, 6, 6]
# Conflicts: 8
# Temperature: 46.17
#
# Current board: [2, 0, 3, 5, 5, 6, 6, 6]
# Conflicts: 9
# Temperature: 45.71
#
# Current board: [2, 0, 3, 5, 5, 6, 6, 6]
# Conflicts: 9
# Temperature: 45.25
#
# Current board: [2, 0, 1, 5, 5, 6, 6, 6]
# Conflicts: 9
# Temperature: 44.80
#
# Current board: [2, 0, 1, 5, 5, 6, 6, 6]
# Conflicts: 9
# Temperature: 44.35
#
# Current board: [2, 0, 1, 5, 1, 6, 6, 6]
# Conflicts: 8
# Temperature: 43.91
#
# Current board: [3, 0, 1, 5, 1, 6, 6, 6]
# Conflicts: 8
# Temperature: 43.47
#
# Current board: [3, 0, 1, 5, 1, 0, 6, 6]
# Conflicts: 8
# Temperature: 43.03
#
# Current board: [3, 0, 1, 5, 1, 0, 2, 6]
# Conflicts: 8
# Temperature: 42.60
#
# Current board: [3, 7, 1, 5, 1, 0, 2, 6]
# Conflicts: 7
# Temperature: 42.18
#
# Current board: [3, 7, 1, 5, 1, 1, 2, 6]
# Conflicts: 9
# Temperature: 41.76
#
# Current board: [3, 7, 1, 5, 1, 1, 2, 1]
# Conflicts: 14
# Temperature: 41.34
#
# Current board: [3, 7, 1, 5, 3, 1, 2, 1]
# Conflicts: 13
# Temperature: 40.93
#
# Current board: [3, 7, 1, 5, 4, 1, 2, 1]
# Conflicts: 15
# Temperature: 40.52
#
# Current board: [3, 7, 1, 5, 4, 7, 2, 1]
# Conflicts: 14
# Temperature: 40.11
#
# Current board: [5, 7, 1, 5, 4, 7, 2, 1]
# Conflicts: 14
# Temperature: 39.71
#
# Current board: [5, 7, 1, 5, 4, 7, 5, 1]
# Conflicts: 13
# Temperature: 39.31
#
# Current board: [5, 7, 1, 4, 4, 7, 5, 1]
# Conflicts: 8
# Temperature: 38.92
#
# Current board: [5, 7, 4, 4, 4, 7, 5, 1]
# Conflicts: 9
# Temperature: 38.53
#
# Current board: [5, 7, 2, 4, 4, 7, 5, 1]
# Conflicts: 7
# Temperature: 38.15
#
# Current board: [5, 7, 2, 4, 4, 2, 5, 1]
# Conflicts: 8
# Temperature: 37.76
#
# Current board: [5, 7, 4, 4, 4, 2, 5, 1]
# Conflicts: 8
# Temperature: 37.39
#
# Current board: [5, 4, 4, 4, 4, 2, 5, 1]
# Conflicts: 10
# Temperature: 37.01
#
# Current board: [5, 4, 4, 4, 4, 2, 5, 1]
# Conflicts: 10
# Temperature: 36.64
#
# Current board: [5, 4, 2, 4, 4, 2, 5, 1]
# Conflicts: 9
# Temperature: 36.28
#
# Current board: [5, 4, 1, 4, 4, 2, 5, 1]
# Conflicts: 9
# Temperature: 35.91
#
# Current board: [5, 4, 1, 4, 4, 7, 5, 1]
# Conflicts: 8
# Temperature: 35.55
#
# Current board: [5, 4, 1, 4, 4, 7, 1, 1]
# Conflicts: 9
# Temperature: 35.20
#
# Current board: [5, 4, 1, 0, 4, 7, 1, 1]
# Conflicts: 7
# Temperature: 34.85
#
# Current board: [5, 4, 1, 0, 4, 7, 6, 1]
# Conflicts: 7
# Temperature: 34.50
#
# Current board: [7, 4, 1, 0, 4, 7, 6, 1]
# Conflicts: 7
# Temperature: 34.15
#
# Current board: [1, 4, 1, 0, 4, 7, 6, 1]
# Conflicts: 8
# Temperature: 33.81
#
# Current board: [1, 4, 1, 0, 6, 7, 6, 1]
# Conflicts: 7
# Temperature: 33.47
#
# Current board: [1, 4, 1, 0, 6, 3, 6, 1]
# Conflicts: 6
# Temperature: 33.14
#
# Current board: [1, 4, 1, 0, 6, 3, 6, 4]
# Conflicts: 5
# Temperature: 32.81
#
# Current board: [1, 4, 1, 0, 6, 3, 6, 4]
# Conflicts: 5
# Temperature: 32.48
#
# Current board: [1, 4, 1, 0, 6, 3, 4, 4]
# Conflicts: 8
# Temperature: 32.15
#
# Current board: [1, 5, 1, 0, 6, 3, 4, 4]
# Conflicts: 6
# Temperature: 31.83
#
# Current board: [1, 5, 1, 0, 6, 3, 4, 4]
# Conflicts: 6
# Temperature: 31.51
#
# Current board: [1, 4, 1, 0, 6, 3, 4, 4]
# Conflicts: 8
# Temperature: 31.20
#
# Current board: [1, 4, 4, 0, 6, 3, 4, 4]
# Conflicts: 10
# Temperature: 30.89
#
# Current board: [1, 1, 4, 0, 6, 3, 4, 4]
# Conflicts: 8
# Temperature: 30.58
#
# Current board: [1, 1, 4, 0, 6, 3, 4, 3]
# Conflicts: 8
# Temperature: 30.27
#
# Current board: [1, 1, 4, 2, 6, 3, 4, 3]
# Conflicts: 8
# Temperature: 29.97
#
# Current board: [1, 1, 4, 2, 6, 3, 4, 3]
# Conflicts: 8
# Temperature: 29.67
#
# Current board: [1, 1, 4, 2, 6, 3, 4, 2]
# Conflicts: 6
# Temperature: 29.37
#
# Current board: [0, 1, 4, 2, 6, 3, 4, 2]
# Conflicts: 6
# Temperature: 29.08
#
# Current board: [0, 1, 4, 2, 2, 3, 4, 2]
# Conflicts: 9
# Temperature: 28.79
#
# Current board: [0, 1, 4, 2, 7, 3, 4, 2]
# Conflicts: 4
# Temperature: 28.50
#
# Current board: [7, 1, 4, 2, 7, 3, 4, 2]
# Conflicts: 4
# Temperature: 28.22
#
# Current board: [7, 1, 4, 2, 7, 3, 4, 7]
# Conflicts: 6
# Temperature: 27.93
#
# Current board: [7, 1, 4, 2, 7, 3, 4, 7]
# Conflicts: 6
# Temperature: 27.65
#
# Current board: [7, 1, 6, 2, 7, 3, 4, 7]
# Conflicts: 6
# Temperature: 27.38
#
# Current board: [7, 1, 6, 5, 7, 3, 4, 7]
# Conflicts: 8
# Temperature: 27.10
#
# Current board: [1, 1, 6, 5, 7, 3, 4, 7]
# Conflicts: 7
# Temperature: 26.83
#
# Current board: [1, 1, 6, 5, 7, 3, 4, 7]
# Conflicts: 7
# Temperature: 26.56
#
# Current board: [1, 1, 6, 5, 7, 3, 4, 7]
# Conflicts: 7
# Temperature: 26.30
#
# Current board: [1, 1, 6, 5, 7, 3, 4, 0]
# Conflicts: 5
# Temperature: 26.04
#
# Current board: [1, 1, 6, 5, 7, 3, 4, 0]
# Conflicts: 5
# Temperature: 25.78
#
# Current board: [1, 1, 6, 5, 7, 3, 0, 0]
# Conflicts: 5
# Temperature: 25.52
#
# Current board: [1, 1, 6, 5, 7, 3, 1, 0]
# Conflicts: 7
# Temperature: 25.26
#
# Current board: [1, 1, 6, 5, 7, 3, 1, 2]
# Conflicts: 7
# Temperature: 25.01
#
# Current board: [1, 3, 6, 5, 7, 3, 1, 2]
# Conflicts: 7
# Temperature: 24.76
#
# Current board: [1, 3, 6, 5, 1, 3, 1, 2]
# Conflicts: 9
# Temperature: 24.51
#
# Current board: [1, 3, 6, 5, 1, 0, 1, 2]
# Conflicts: 9
# Temperature: 24.27
#
# Current board: [1, 3, 6, 0, 1, 0, 1, 2]
# Conflicts: 9
# Temperature: 24.02
#
# Current board: [1, 3, 6, 0, 4, 0, 1, 2]
# Conflicts: 6
# Temperature: 23.78
#
# Current board: [1, 3, 6, 0, 4, 3, 1, 2]
# Conflicts: 6
# Temperature: 23.55
#
# Current board: [1, 3, 6, 0, 0, 3, 1, 2]
# Conflicts: 6
# Temperature: 23.31
#
# Current board: [1, 3, 6, 0, 1, 3, 1, 2]
# Conflicts: 7
# Temperature: 23.08
#
# Current board: [1, 3, 6, 0, 1, 6, 1, 2]
# Conflicts: 7
# Temperature: 22.85
#
# Current board: [1, 3, 6, 0, 3, 6, 1, 2]
# Conflicts: 6
# Temperature: 22.62
#
# Current board: [1, 3, 6, 0, 5, 6, 1, 2]
# Conflicts: 7
# Temperature: 22.39
#
# Current board: [1, 3, 6, 0, 5, 6, 1, 4]
# Conflicts: 7
# Temperature: 22.17
#
# Current board: [1, 3, 7, 0, 5, 6, 1, 4]
# Conflicts: 7
# Temperature: 21.95
#
# Current board: [1, 4, 7, 0, 5, 6, 1, 4]
# Conflicts: 8
# Temperature: 21.73
#
# Current board: [4, 4, 7, 0, 5, 6, 1, 4]
# Conflicts: 7
# Temperature: 21.51
#
# Current board: [4, 7, 7, 0, 5, 6, 1, 4]
# Conflicts: 6
# Temperature: 21.30
#
# Current board: [4, 7, 7, 0, 2, 6, 1, 4]
# Conflicts: 4
# Temperature: 21.08
#
# Current board: [4, 7, 7, 0, 2, 6, 1, 4]
# Conflicts: 4
# Temperature: 20.87
#
# Current board: [2, 7, 7, 0, 2, 6, 1, 4]
# Conflicts: 4
# Temperature: 20.66
#
# Current board: [2, 4, 7, 0, 2, 6, 1, 4]
# Conflicts: 4
# Temperature: 20.46
#
# Current board: [2, 1, 7, 0, 2, 6, 1, 4]
# Conflicts: 5
# Temperature: 20.25
#
# Current board: [2, 1, 7, 0, 3, 6, 1, 4]
# Conflicts: 5
# Temperature: 20.05
#
# Current board: [2, 1, 7, 0, 3, 6, 1, 1]
# Conflicts: 5
# Temperature: 19.85
#
# Current board: [2, 1, 3, 0, 3, 6, 1, 1]
# Conflicts: 7
# Temperature: 19.65
#
# Current board: [2, 1, 1, 0, 3, 6, 1, 1]
# Conflicts: 10
# Temperature: 19.45
#
# Current board: [2, 1, 1, 0, 3, 6, 1, 1]
# Conflicts: 10
# Temperature: 19.26
#
# Current board: [2, 1, 1, 0, 3, 6, 1, 1]
# Conflicts: 10
# Temperature: 19.07
#
# Current board: [2, 1, 1, 0, 3, 6, 1, 0]
# Conflicts: 10
# Temperature: 18.88
#
# Current board: [2, 1, 5, 0, 3, 6, 1, 0]
# Conflicts: 9
# Temperature: 18.69
#
# Current board: [2, 1, 5, 6, 3, 6, 1, 0]
# Conflicts: 10
# Temperature: 18.50
#
# Current board: [2, 1, 5, 6, 4, 6, 1, 0]
# Conflicts: 8
# Temperature: 18.32
#
# Current board: [7, 1, 5, 6, 4, 6, 1, 0]
# Conflicts: 10
# Temperature: 18.13
#
# Current board: [2, 1, 5, 6, 4, 6, 1, 0]
# Conflicts: 8
# Temperature: 17.95
#
# Current board: [2, 1, 1, 6, 4, 6, 1, 0]
# Conflicts: 7
# Temperature: 17.77
#
# Current board: [2, 1, 1, 6, 4, 6, 1, 0]
# Conflicts: 7
# Temperature: 17.59
#
# Current board: [2, 3, 1, 6, 4, 6, 1, 0]
# Conflicts: 4
# Temperature: 17.42
#
# Current board: [3, 3, 1, 6, 4, 6, 1, 0]
# Conflicts: 6
# Temperature: 17.24
#
# Current board: [3, 3, 3, 6, 4, 6, 1, 0]
# Conflicts: 7
# Temperature: 17.07
#
# Current board: [3, 3, 3, 1, 4, 6, 1, 0]
# Conflicts: 7
# Temperature: 16.90
#
# Current board: [3, 3, 3, 1, 4, 6, 1, 0]
# Conflicts: 7
# Temperature: 16.73
#
# Current board: [3, 3, 3, 1, 4, 4, 1, 0]
# Conflicts: 7
# Temperature: 16.56
#
# Current board: [3, 3, 3, 1, 5, 4, 1, 0]
# Conflicts: 8
# Temperature: 16.40
#
# Current board: [3, 4, 3, 1, 5, 4, 1, 0]
# Conflicts: 8
# Temperature: 16.23
#
# Current board: [3, 4, 3, 1, 4, 4, 1, 0]
# Conflicts: 8
# Temperature: 16.07
#
# Current board: [3, 4, 3, 1, 4, 2, 1, 0]
# Conflicts: 8
# Temperature: 15.91
#
# Current board: [3, 7, 3, 1, 4, 2, 1, 0]
# Conflicts: 6
# Temperature: 15.75
#
# Current board: [3, 7, 3, 2, 4, 2, 1, 0]
# Conflicts: 7
# Temperature: 15.59
#
# Current board: [3, 7, 3, 2, 4, 2, 1, 0]
# Conflicts: 7
# Temperature: 15.44
#
# Current board: [3, 7, 3, 2, 4, 2, 4, 0]
# Conflicts: 6
# Temperature: 15.28
#
# Current board: [3, 5, 3, 2, 4, 2, 4, 0]
# Conflicts: 5
# Temperature: 15.13
#
# Current board: [3, 5, 3, 2, 3, 2, 4, 0]
# Conflicts: 9
# Temperature: 14.98
#
# Current board: [7, 5, 3, 2, 3, 2, 4, 0]
# Conflicts: 10
# Temperature: 14.83
#
# Current board: [7, 5, 3, 2, 3, 7, 4, 0]
# Conflicts: 7
# Temperature: 14.68
#
# Current board: [7, 5, 5, 2, 3, 7, 4, 0]
# Conflicts: 9
# Temperature: 14.54
#
# Current board: [4, 5, 5, 2, 3, 7, 4, 0]
# Conflicts: 7
# Temperature: 14.39
#
# Current board: [4, 5, 5, 2, 3, 7, 6, 0]
# Conflicts: 7
# Temperature: 14.25
#
# Current board: [1, 5, 5, 2, 3, 7, 6, 0]
# Conflicts: 6
# Temperature: 14.10
#
# Current board: [1, 5, 5, 3, 3, 7, 6, 0]
# Conflicts: 8
# Temperature: 13.96
#
# Current board: [1, 5, 5, 3, 3, 6, 6, 0]
# Conflicts: 9
# Temperature: 13.82
#
# Current board: [6, 5, 5, 3, 3, 6, 6, 0]
# Conflicts: 12
# Temperature: 13.68
#
# Current board: [6, 5, 5, 3, 3, 6, 7, 0]
# Conflicts: 10
# Temperature: 13.55
#
# Current board: [6, 5, 5, 4, 3, 6, 7, 0]
# Conflicts: 12
# Temperature: 13.41
#
# Current board: [6, 4, 5, 4, 3, 6, 7, 0]
# Conflicts: 12
# Temperature: 13.28
#
# Current board: [6, 2, 5, 4, 3, 6, 7, 0]
# Conflicts: 13
# Temperature: 13.15
#
# Current board: [6, 2, 5, 7, 3, 6, 7, 0]
# Conflicts: 8
# Temperature: 13.01
#
# Current board: [6, 2, 5, 6, 3, 6, 7, 0]
# Conflicts: 10
# Temperature: 12.88
#
# Current board: [6, 2, 5, 6, 3, 3, 7, 0]
# Conflicts: 7
# Temperature: 12.75
#
# Current board: [6, 2, 5, 6, 0, 3, 7, 0]
# Conflicts: 5
# Temperature: 12.63
#
# Current board: [6, 2, 5, 1, 0, 3, 7, 0]
# Conflicts: 5
# Temperature: 12.50
#
# Current board: [6, 2, 5, 1, 0, 3, 7, 2]
# Conflicts: 4
# Temperature: 12.38
#
# Current board: [6, 2, 5, 1, 0, 3, 7, 2]
# Conflicts: 4
# Temperature: 12.25
#
# Current board: [6, 2, 5, 1, 0, 3, 7, 2]
# Conflicts: 4
# Temperature: 12.13
#
# Current board: [6, 2, 5, 1, 0, 3, 7, 2]
# Conflicts: 4
# Temperature: 12.01
#
# Current board: [6, 2, 5, 1, 0, 0, 7, 2]
# Conflicts: 5
# Temperature: 11.89
#
# Current board: [6, 2, 5, 1, 0, 0, 7, 2]
# Conflicts: 5
# Temperature: 11.77
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 2]
# Conflicts: 5
# Temperature: 11.65
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 2]
# Conflicts: 5
# Temperature: 11.54
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 2]
# Conflicts: 5
# Temperature: 11.42
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 7]
# Conflicts: 4
# Temperature: 11.31
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 7]
# Conflicts: 4
# Temperature: 11.19
#
# Current board: [6, 2, 5, 5, 0, 0, 7, 7]
# Conflicts: 4
# Temperature: 11.08
#
# Current board: [6, 2, 5, 5, 6, 0, 7, 7]
# Conflicts: 5
# Temperature: 10.97
#
# Current board: [6, 2, 5, 5, 6, 0, 4, 7]
# Conflicts: 4
# Temperature: 10.86
#
# Current board: [6, 3, 5, 5, 6, 0, 4, 7]
# Conflicts: 6
# Temperature: 10.75
#
# Current board: [6, 3, 5, 4, 6, 0, 4, 7]
# Conflicts: 5
# Temperature: 10.64
#
# Current board: [6, 3, 5, 1, 6, 0, 4, 7]
# Conflicts: 5
# Temperature: 10.54
#
# Current board: [6, 3, 1, 1, 6, 0, 4, 7]
# Conflicts: 6
# Temperature: 10.43
#
# Current board: [6, 3, 1, 1, 6, 0, 2, 7]
# Conflicts: 4
# Temperature: 10.33
#
# Current board: [0, 3, 1, 1, 6, 0, 2, 7]
# Conflicts: 5
# Temperature: 10.22
#
# Current board: [0, 3, 1, 6, 6, 0, 2, 7]
# Conflicts: 4
# Temperature: 10.12
#
# Current board: [0, 3, 1, 6, 6, 0, 2, 7]
# Conflicts: 4
# Temperature: 10.02
#
# Current board: [0, 3, 1, 6, 6, 4, 2, 7]
# Conflicts: 5
# Temperature: 9.92
#
# Current board: [0, 3, 1, 6, 6, 7, 2, 7]
# Conflicts: 6
# Temperature: 9.82
#
# Current board: [0, 3, 1, 6, 6, 2, 2, 7]
# Conflicts: 4
# Temperature: 9.72
#
# Current board: [6, 3, 1, 6, 6, 2, 2, 7]
# Conflicts: 5
# Temperature: 9.63
#
# Current board: [6, 3, 1, 6, 6, 2, 5, 7]
# Conflicts: 5
# Temperature: 9.53
#
# Current board: [6, 3, 1, 6, 6, 2, 5, 7]
# Conflicts: 5
# Temperature: 9.43
#
# Current board: [6, 3, 1, 6, 6, 0, 5, 7]
# Conflicts: 5
# Temperature: 9.34
#
# Current board: [6, 3, 1, 6, 6, 2, 5, 7]
# Conflicts: 5
# Temperature: 9.25
#
# Current board: [6, 3, 1, 3, 6, 2, 5, 7]
# Conflicts: 6
# Temperature: 9.15
#
# Current board: [6, 3, 1, 3, 5, 2, 5, 7]
# Conflicts: 5
# Temperature: 9.06
#
# Current board: [6, 3, 1, 3, 5, 2, 5, 3]
# Conflicts: 6
# Temperature: 8.97
#
# Current board: [6, 0, 1, 3, 5, 2, 5, 3]
# Conflicts: 6
# Temperature: 8.88
#
# Current board: [6, 0, 1, 3, 7, 2, 5, 3]
# Conflicts: 6
# Temperature: 8.79
#
# Current board: [6, 0, 1, 3, 7, 2, 5, 3]
# Conflicts: 6
# Temperature: 8.71
#
# Current board: [6, 0, 1, 3, 7, 2, 0, 3]
# Conflicts: 6
# Temperature: 8.62
#
# Current board: [7, 0, 1, 3, 7, 2, 0, 3]
# Conflicts: 6
# Temperature: 8.53
#
# Current board: [7, 0, 1, 3, 5, 2, 0, 3]
# Conflicts: 5
# Temperature: 8.45
#
# Current board: [7, 2, 1, 3, 5, 2, 0, 3]
# Conflicts: 6
# Temperature: 8.36
#
# Current board: [7, 2, 1, 3, 0, 2, 0, 3]
# Conflicts: 7
# Temperature: 8.28
#
# Current board: [7, 2, 2, 3, 0, 2, 0, 3]
# Conflicts: 10
# Temperature: 8.20
#
# Current board: [7, 0, 2, 3, 0, 2, 0, 3]
# Conflicts: 10
# Temperature: 8.11
#
# Current board: [7, 0, 7, 3, 0, 2, 0, 3]
# Conflicts: 8
# Temperature: 8.03
#
# Current board: [7, 0, 7, 3, 0, 2, 0, 3]
# Conflicts: 8
# Temperature: 7.95
#
# Current board: [7, 0, 3, 3, 0, 2, 0, 3]
# Conflicts: 9
# Temperature: 7.87
#
# Current board: [7, 0, 3, 3, 0, 2, 0, 3]
# Conflicts: 9
# Temperature: 7.79
#
# Current board: [7, 0, 3, 3, 0, 2, 0, 3]
# Conflicts: 9
# Temperature: 7.72
#
# Current board: [7, 0, 3, 3, 0, 6, 0, 3]
# Conflicts: 9
# Temperature: 7.64
#
# Current board: [7, 7, 3, 3, 0, 6, 0, 3]
# Conflicts: 8
# Temperature: 7.56
#
# Current board: [7, 0, 3, 3, 0, 6, 0, 3]
# Conflicts: 9
# Temperature: 7.49
#
# Current board: [7, 0, 3, 3, 0, 6, 0, 7]
# Conflicts: 8
# Temperature: 7.41
#
# Current board: [3, 0, 3, 3, 0, 6, 0, 7]
# Conflicts: 9
# Temperature: 7.34
#
# Current board: [3, 0, 2, 3, 0, 6, 0, 7]
# Conflicts: 9
# Temperature: 7.27
#
# Current board: [3, 0, 2, 3, 6, 6, 0, 7]
# Conflicts: 7
# Temperature: 7.19
#
# Current board: [3, 0, 2, 3, 6, 6, 0, 1]
# Conflicts: 6
# Temperature: 7.12
#
# Current board: [3, 0, 2, 3, 5, 6, 0, 1]
# Conflicts: 6
# Temperature: 7.05
#
# Current board: [3, 0, 2, 3, 5, 6, 6, 1]
# Conflicts: 6
# Temperature: 6.98
#
# Current board: [3, 0, 2, 3, 5, 6, 6, 0]
# Conflicts: 7
# Temperature: 6.91
#
# Current board: [3, 3, 2, 3, 5, 6, 6, 0]
# Conflicts: 9
# Temperature: 6.84
#
# Current board: [4, 3, 2, 3, 5, 6, 6, 0]
# Conflicts: 9
# Temperature: 6.77
#
# Current board: [4, 3, 0, 3, 5, 6, 6, 0]
# Conflicts: 6
# Temperature: 6.70
#
# Current board: [4, 3, 0, 4, 5, 6, 6, 0]
# Conflicts: 8
# Temperature: 6.64
#
# Current board: [4, 3, 0, 4, 5, 6, 6, 4]
# Conflicts: 9
# Temperature: 6.57
#
# Current board: [4, 3, 5, 4, 5, 6, 6, 4]
# Conflicts: 11
# Temperature: 6.50
#
# Current board: [0, 3, 5, 4, 5, 6, 6, 4]
# Conflicts: 9
# Temperature: 6.44
#
# Current board: [0, 3, 5, 4, 0, 6, 6, 4]
# Conflicts: 8
# Temperature: 6.38
#
# Current board: [0, 3, 6, 4, 0, 6, 6, 4]
# Conflicts: 9
# Temperature: 6.31
#
# Current board: [0, 3, 6, 4, 3, 6, 6, 4]
# Conflicts: 9
# Temperature: 6.25
#
# Current board: [0, 3, 6, 4, 3, 5, 6, 4]
# Conflicts: 7
# Temperature: 6.19
#
# Current board: [0, 3, 6, 4, 3, 5, 6, 3]
# Conflicts: 9
# Temperature: 6.12
#
# Current board: [0, 3, 6, 4, 3, 2, 6, 3]
# Conflicts: 8
# Temperature: 6.06
#
# Current board: [0, 3, 6, 4, 3, 2, 6, 3]
# Conflicts: 8
# Temperature: 6.00
#
# Current board: [0, 3, 6, 4, 3, 2, 6, 3]
# Conflicts: 8
# Temperature: 5.94
#
# Current board: [5, 3, 6, 4, 3, 2, 6, 3]
# Conflicts: 7
# Temperature: 5.88
#
# Current board: [5, 3, 7, 4, 3, 2, 6, 3]
# Conflicts: 7
# Temperature: 5.82
#
# Current board: [5, 1, 7, 4, 3, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.77
#
# Current board: [5, 1, 7, 4, 3, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.71
#
# Current board: [5, 1, 7, 4, 1, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.65
#
# Current board: [5, 1, 0, 4, 1, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.59
#
# Current board: [5, 1, 0, 6, 1, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.54
#
# Current board: [5, 1, 0, 6, 1, 2, 6, 3]
# Conflicts: 6
# Temperature: 5.48
#
# Current board: [5, 2, 0, 6, 1, 2, 6, 3]
# Conflicts: 4
# Temperature: 5.43
#
# Current board: [5, 2, 0, 0, 1, 2, 6, 3]
# Conflicts: 7
# Temperature: 5.37
#
# Current board: [5, 2, 0, 0, 1, 2, 3, 3]
# Conflicts: 11
# Temperature: 5.32
#
# Current board: [5, 2, 0, 4, 1, 2, 3, 3]
# Conflicts: 8
# Temperature: 5.27
#
# Current board: [5, 2, 0, 4, 1, 2, 3, 3]
# Conflicts: 8
# Temperature: 5.21
#
# Current board: [5, 2, 0, 4, 1, 2, 3, 3]
# Conflicts: 8
# Temperature: 5.16
#
# Current board: [5, 2, 0, 4, 1, 2, 3, 5]
# Conflicts: 9
# Temperature: 5.11
#
# Current board: [5, 2, 4, 4, 1, 2, 3, 5]
# Conflicts: 9
# Temperature: 5.06
#
# Current board: [5, 6, 4, 4, 1, 2, 3, 5]
# Conflicts: 10
# Temperature: 5.01
#
# Current board: [5, 6, 4, 6, 1, 2, 3, 5]
# Conflicts: 9
# Temperature: 4.96
#
# Current board: [5, 5, 4, 6, 1, 2, 3, 5]
# Conflicts: 9
# Temperature: 4.91
#
# Current board: [5, 5, 4, 6, 1, 6, 3, 5]
# Conflicts: 8
# Temperature: 4.86
#
# Current board: [1, 5, 4, 6, 1, 6, 3, 5]
# Conflicts: 7
# Temperature: 4.81
#
# Current board: [1, 0, 4, 6, 1, 6, 3, 5]
# Conflicts: 6
# Temperature: 4.76
#
# Current board: [1, 0, 4, 6, 1, 6, 6, 5]
# Conflicts: 7
# Temperature: 4.72
#
# Current board: [5, 0, 4, 6, 1, 6, 6, 5]
# Conflicts: 6
# Temperature: 4.67
#
# Current board: [5, 0, 4, 6, 1, 6, 6, 5]
# Conflicts: 6
# Temperature: 4.62
#
# Current board: [5, 0, 4, 6, 1, 6, 6, 0]
# Conflicts: 5
# Temperature: 4.58
#
# Current board: [5, 0, 4, 6, 1, 6, 6, 1]
# Conflicts: 5
# Temperature: 4.53
#
# Current board: [5, 0, 4, 6, 7, 6, 6, 1]
# Conflicts: 5
# Temperature: 4.48
#
# Current board: [5, 0, 4, 6, 7, 6, 6, 1]
# Conflicts: 5
# Temperature: 4.44
#
# Current board: [5, 0, 4, 6, 7, 2, 6, 1]
# Conflicts: 2
# Temperature: 4.40
#
# Current board: [5, 0, 4, 6, 7, 2, 6, 1]
# Conflicts: 2
# Temperature: 4.35
#
# Current board: [5, 0, 4, 6, 7, 1, 6, 1]
# Conflicts: 4
# Temperature: 4.31
#
# Current board: [5, 0, 4, 1, 7, 1, 6, 1]
# Conflicts: 4
# Temperature: 4.26
#
# Current board: [5, 0, 4, 1, 7, 1, 6, 0]
# Conflicts: 3
# Temperature: 4.22
#
# Current board: [5, 0, 4, 1, 2, 1, 6, 0]
# Conflicts: 6
# Temperature: 4.18
#
# Current board: [5, 0, 5, 1, 2, 1, 6, 0]
# Conflicts: 6
# Temperature: 4.14
#
# Current board: [5, 0, 5, 1, 2, 6, 6, 0]
# Conflicts: 5
# Temperature: 4.10
#
# Current board: [5, 0, 5, 1, 2, 6, 6, 7]
# Conflicts: 4
# Temperature: 4.06
#
# Current board: [5, 0, 5, 7, 2, 6, 6, 7]
# Conflicts: 4
# Temperature: 4.02
#
# Current board: [5, 0, 5, 7, 2, 6, 1, 7]
# Conflicts: 3
# Temperature: 3.98
#
# Current board: [5, 0, 5, 7, 2, 6, 1, 6]
# Conflicts: 4
# Temperature: 3.94
#
# Current board: [5, 0, 5, 7, 2, 6, 1, 6]
# Conflicts: 4
# Temperature: 3.90
#
# Current board: [6, 0, 5, 7, 2, 6, 1, 6]
# Conflicts: 6
# Temperature: 3.86
#
# Current board: [6, 0, 5, 7, 5, 6, 1, 6]
# Conflicts: 7
# Temperature: 3.82
#
# Current board: [6, 0, 5, 7, 5, 6, 1, 6]
# Conflicts: 7
# Temperature: 3.78
#
# Current board: [6, 0, 5, 1, 5, 6, 1, 6]
# Conflicts: 8
# Temperature: 3.74
#
# Current board: [6, 0, 5, 7, 5, 6, 1, 6]
# Conflicts: 7
# Temperature: 3.71
#
# Current board: [6, 7, 5, 7, 5, 6, 1, 6]
# Conflicts: 8
# Temperature: 3.67
#
# Current board: [6, 7, 5, 7, 5, 6, 1, 6]
# Conflicts: 8
# Temperature: 3.63
#
# Current board: [6, 7, 5, 7, 5, 6, 4, 6]
# Conflicts: 8
# Temperature: 3.60
#
# Current board: [6, 7, 5, 7, 5, 6, 4, 1]
# Conflicts: 7
# Temperature: 3.56
#
# Current board: [6, 7, 5, 7, 5, 6, 4, 1]
# Conflicts: 7
# Temperature: 3.52
#
# Current board: [6, 7, 5, 7, 5, 6, 4, 1]
# Conflicts: 7
# Temperature: 3.49
#
# Current board: [6, 7, 5, 3, 5, 6, 4, 1]
# Conflicts: 6
# Temperature: 3.45
#
# Current board: [6, 7, 5, 3, 6, 6, 4, 1]
# Conflicts: 7
# Temperature: 3.42
#
# Current board: [6, 7, 5, 3, 6, 6, 4, 1]
# Conflicts: 7
# Temperature: 3.38
#
# Current board: [6, 7, 3, 3, 6, 6, 4, 1]
# Conflicts: 9
# Temperature: 3.35
#
# Current board: [6, 7, 3, 1, 6, 6, 4, 1]
# Conflicts: 9
# Temperature: 3.32
#
# Current board: [6, 7, 3, 1, 6, 6, 4, 1]
# Conflicts: 9
# Temperature: 3.28
#
# Current board: [6, 7, 3, 1, 6, 6, 4, 1]
# Conflicts: 9
# Temperature: 3.25
#
# Current board: [6, 2, 3, 1, 6, 6, 4, 1]
# Conflicts: 9
# Temperature: 3.22
#
# Current board: [6, 2, 3, 1, 6, 6, 1, 1]
# Conflicts: 9
# Temperature: 3.19
#
# Current board: [6, 1, 3, 1, 6, 6, 1, 1]
# Conflicts: 10
# Temperature: 3.15
#
# Current board: [6, 1, 4, 1, 6, 6, 1, 1]
# Conflicts: 11
# Temperature: 3.12
#
# Current board: [5, 1, 4, 1, 6, 6, 1, 1]
# Conflicts: 8
# Temperature: 3.09
#
# Current board: [0, 1, 4, 1, 6, 6, 1, 1]
# Conflicts: 9
# Temperature: 3.06
#
# Current board: [0, 6, 4, 1, 6, 6, 1, 1]
# Conflicts: 8
# Temperature: 3.03
#
# Current board: [0, 0, 4, 1, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 3.00
#
# Current board: [0, 0, 4, 1, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 2.97
#
# Current board: [0, 0, 4, 0, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 2.94
#
# Current board: [0, 0, 4, 0, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 2.91
#
# Current board: [0, 0, 4, 0, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 2.88
#
# Current board: [0, 0, 4, 0, 6, 6, 1, 1]
# Conflicts: 6
# Temperature: 2.85
#
# Current board: [1, 0, 4, 0, 6, 6, 1, 1]
# Conflicts: 8
# Temperature: 2.82
#
# Current board: [1, 5, 4, 0, 6, 6, 1, 1]
# Conflicts: 7
# Temperature: 2.80
#
# Current board: [1, 5, 4, 0, 6, 6, 1, 6]
# Conflicts: 7
# Temperature: 2.77
#
# Current board: [1, 5, 4, 0, 6, 1, 1, 6]
# Conflicts: 8
# Temperature: 2.74
#
# Current board: [1, 5, 4, 0, 6, 1, 1, 6]
# Conflicts: 8
# Temperature: 2.71
#
# Current board: [1, 5, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.69
#
# Current board: [1, 5, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.66
#
# Current board: [1, 5, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.63
#
# Current board: [1, 5, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.61
#
# Current board: [1, 5, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.58
#
# Current board: [1, 1, 4, 0, 6, 1, 4, 6]
# Conflicts: 8
# Temperature: 2.55
#
# Current board: [1, 1, 4, 0, 1, 1, 4, 6]
# Conflicts: 9
# Temperature: 2.53
#
# Current board: [1, 1, 4, 0, 1, 1, 5, 6]
# Conflicts: 9
# Temperature: 2.50
#
# Current board: [1, 1, 4, 0, 1, 1, 0, 6]
# Conflicts: 11
# Temperature: 2.48
#
# Current board: [6, 1, 4, 0, 1, 1, 0, 6]
# Conflicts: 12
# Temperature: 2.45
#
# Current board: [5, 1, 4, 0, 1, 1, 0, 6]
# Conflicts: 9
# Temperature: 2.43
#
# Current board: [5, 1, 4, 5, 1, 1, 0, 6]
# Conflicts: 9
# Temperature: 2.41
#
# Current board: [5, 1, 4, 5, 1, 6, 0, 6]
# Conflicts: 6
# Temperature: 2.38
#
# Current board: [5, 1, 4, 5, 1, 6, 0, 6]
# Conflicts: 6
# Temperature: 2.36
#
# Current board: [5, 1, 4, 5, 1, 6, 0, 2]
# Conflicts: 5
# Temperature: 2.33
#
# Current board: [7, 1, 4, 5, 1, 6, 0, 2]
# Conflicts: 3
# Temperature: 2.31
#
# Current board: [7, 1, 4, 5, 1, 0, 0, 2]
# Conflicts: 6
# Temperature: 2.29
#
# Current board: [7, 1, 4, 1, 1, 0, 0, 2]
# Conflicts: 7
# Temperature: 2.26
#
# Current board: [7, 1, 4, 1, 6, 0, 0, 2]
# Conflicts: 5
# Temperature: 2.24
#
# Current board: [6, 1, 4, 1, 6, 0, 0, 2]
# Conflicts: 8
# Temperature: 2.22
#
# Current board: [6, 1, 4, 1, 6, 5, 0, 2]
# Conflicts: 8
# Temperature: 2.20
#
# Current board: [6, 1, 4, 1, 6, 5, 0, 2]
# Conflicts: 8
# Temperature: 2.18
#
# Current board: [3, 1, 4, 1, 6, 5, 0, 2]
# Conflicts: 5
# Temperature: 2.15
#
# Current board: [3, 1, 4, 1, 6, 5, 0, 0]
# Conflicts: 6
# Temperature: 2.13
#
# Current board: [3, 1, 4, 1, 6, 5, 0, 0]
# Conflicts: 6
# Temperature: 2.11
#
# Current board: [3, 1, 4, 1, 6, 5, 0, 0]
# Conflicts: 6
# Temperature: 2.09
#
# Current board: [3, 4, 4, 1, 6, 5, 0, 0]
# Conflicts: 6
# Temperature: 2.07
#
# Current board: [3, 4, 4, 1, 6, 5, 0, 0]
# Conflicts: 6
# Temperature: 2.05
#
# Current board: [3, 4, 4, 1, 0, 5, 0, 0]
# Conflicts: 7
# Temperature: 2.03
#
# Current board: [3, 4, 4, 1, 0, 5, 0, 0]
# Conflicts: 7
# Temperature: 2.01
#
# Current board: [3, 4, 4, 1, 0, 5, 2, 0]
# Conflicts: 5
# Temperature: 1.99
#
# Current board: [3, 4, 4, 1, 0, 5, 2, 0]
# Conflicts: 5
# Temperature: 1.97
#
# Current board: [3, 5, 4, 1, 0, 5, 2, 0]
# Conflicts: 5
# Temperature: 1.95
#
# Current board: [3, 5, 4, 1, 0, 5, 2, 0]
# Conflicts: 5
# Temperature: 1.93
#
# Current board: [3, 5, 7, 1, 0, 5, 2, 0]
# Conflicts: 4
# Temperature: 1.91
#
# Current board: [3, 5, 7, 1, 0, 5, 2, 3]
# Conflicts: 7
# Temperature: 1.89
#
# Current board: [3, 5, 7, 1, 0, 1, 2, 3]
# Conflicts: 10
# Temperature: 1.87
#
# Current board: [3, 5, 7, 1, 0, 1, 2, 3]
# Conflicts: 10
# Temperature: 1.85
#
# Current board: [3, 5, 7, 1, 0, 3, 2, 3]
# Conflicts: 9
# Temperature: 1.83
#
# Current board: [3, 5, 7, 0, 0, 3, 2, 3]
# Conflicts: 9
# Temperature: 1.82
#
# Current board: [3, 5, 7, 0, 5, 3, 2, 3]
# Conflicts: 8
# Temperature: 1.80
#
# Current board: [5, 5, 7, 0, 5, 3, 2, 3]
# Conflicts: 8
# Temperature: 1.78
#
# Current board: [5, 5, 2, 0, 5, 3, 2, 3]
# Conflicts: 7
# Temperature: 1.76
#
# Current board: [5, 5, 2, 0, 1, 3, 2, 3]
# Conflicts: 7
# Temperature: 1.74
#
# Current board: [6, 5, 2, 0, 1, 3, 2, 3]
# Conflicts: 6
# Temperature: 1.73
#
# Current board: [6, 5, 2, 0, 1, 3, 2, 7]
# Conflicts: 5
# Temperature: 1.71
#
# Current board: [6, 5, 2, 0, 1, 3, 2, 7]
# Conflicts: 5
# Temperature: 1.69
#
# Current board: [6, 5, 2, 0, 1, 3, 2, 7]
# Conflicts: 5
# Temperature: 1.67
#
# Current board: [6, 5, 2, 0, 1, 3, 3, 7]
# Conflicts: 6
# Temperature: 1.66
#
# Current board: [6, 5, 2, 0, 1, 3, 3, 7]
# Conflicts: 6
# Temperature: 1.64
#
# Current board: [6, 5, 2, 0, 1, 3, 3, 7]
# Conflicts: 6
# Temperature: 1.63
#
# Current board: [6, 1, 2, 0, 1, 3, 3, 7]
# Conflicts: 8
# Temperature: 1.61
#
# Current board: [7, 1, 2, 0, 1, 3, 3, 7]
# Conflicts: 9
# Temperature: 1.59
#
# Current board: [7, 1, 2, 0, 1, 3, 3, 7]
# Conflicts: 9
# Temperature: 1.58
#
# Current board: [7, 1, 2, 0, 1, 3, 3, 7]
# Conflicts: 9
# Temperature: 1.56
#
# Current board: [7, 4, 2, 0, 1, 3, 3, 7]
# Conflicts: 7
# Temperature: 1.55
#
# Current board: [2, 4, 2, 0, 1, 3, 3, 7]
# Conflicts: 7
# Temperature: 1.53
#
# Current board: [6, 4, 2, 0, 1, 3, 3, 7]
# Conflicts: 6
# Temperature: 1.51
#
# Current board: [6, 4, 2, 0, 1, 7, 3, 7]
# Conflicts: 6
# Temperature: 1.50
#
# Current board: [6, 4, 2, 0, 1, 7, 3, 7]
# Conflicts: 6
# Temperature: 1.48
#
# Current board: [6, 4, 2, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.47
#
# Current board: [6, 4, 2, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.46
#
# Current board: [6, 4, 2, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.44
#
# Current board: [6, 4, 2, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.43
#
# Current board: [6, 4, 2, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.41
#
# Current board: [6, 4, 5, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.40
#
# Current board: [6, 4, 5, 0, 1, 7, 4, 7]
# Conflicts: 5
# Temperature: 1.38
#
# Current board: [6, 4, 5, 0, 6, 7, 4, 7]
# Conflicts: 6
# Temperature: 1.37
#
# Current board: [6, 4, 6, 0, 6, 7, 4, 7]
# Conflicts: 7
# Temperature: 1.36
#
# Current board: [6, 4, 6, 0, 6, 7, 4, 7]
# Conflicts: 7
# Temperature: 1.34
#
# Current board: [6, 0, 6, 0, 6, 7, 4, 7]
# Conflicts: 7
# Temperature: 1.33
#
# Current board: [6, 0, 6, 0, 6, 7, 4, 7]
# Conflicts: 7
# Temperature: 1.32
#
# Current board: [6, 0, 6, 0, 6, 7, 4, 7]
# Conflicts: 7
# Temperature: 1.30
#
# Current board: [6, 0, 6, 0, 6, 7, 5, 7]
# Conflicts: 7
# Temperature: 1.29
#
# Current board: [6, 0, 6, 0, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.28
#
# Current board: [6, 0, 6, 0, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.26
#
# Current board: [6, 0, 0, 0, 5, 7, 5, 7]
# Conflicts: 6
# Temperature: 1.25
#
# Current board: [6, 0, 0, 4, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.24
#
# Current board: [6, 0, 6, 4, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.23
#
# Current board: [6, 0, 6, 4, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.21
#
# Current board: [6, 0, 6, 4, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.20
#
# Current board: [6, 0, 6, 4, 5, 7, 5, 7]
# Conflicts: 5
# Temperature: 1.19
#
# Current board: [6, 0, 6, 4, 5, 7, 5, 1]
# Conflicts: 5
# Temperature: 1.18
#
# Current board: [6, 0, 6, 4, 5, 7, 2, 1]
# Conflicts: 5
# Temperature: 1.17
#
# Current board: [6, 5, 6, 4, 5, 7, 2, 1]
# Conflicts: 8
# Temperature: 1.15
#
# Current board: [6, 5, 6, 4, 5, 7, 2, 0]
# Conflicts: 7
# Temperature: 1.14
#
# Current board: [6, 5, 6, 4, 5, 7, 2, 0]
# Conflicts: 7
# Temperature: 1.13
#
# Current board: [6, 5, 6, 4, 5, 7, 2, 0]
# Conflicts: 7
# Temperature: 1.12
#
# Current board: [6, 5, 6, 4, 1, 7, 2, 0]
# Conflicts: 5
# Temperature: 1.11
#
# Current board: [6, 5, 6, 4, 1, 7, 2, 0]
# Conflicts: 5
# Temperature: 1.10
#
# Current board: [6, 5, 6, 4, 1, 7, 2, 0]
# Conflicts: 5
# Temperature: 1.09
#
# Current board: [6, 5, 6, 4, 1, 7, 2, 0]
# Conflicts: 5
# Temperature: 1.08
#
# Current board: [6, 5, 6, 4, 1, 7, 2, 2]
# Conflicts: 5
# Temperature: 1.07
#
# Current board: [6, 6, 6, 4, 1, 7, 2, 2]
# Conflicts: 6
# Temperature: 1.05
#
# Current board: [6, 6, 6, 4, 1, 7, 0, 2]
# Conflicts: 5
# Temperature: 1.04
#
# Current board: [6, 6, 6, 4, 1, 7, 0, 2]
# Conflicts: 5
# Temperature: 1.03
#
# Current board: [6, 6, 6, 4, 1, 7, 4, 2]
# Conflicts: 5
# Temperature: 1.02
#
# Current board: [6, 2, 6, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 1.01
#
# Current board: [6, 2, 6, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 1.00
#
# Current board: [6, 2, 6, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 0.99
#
# Current board: [6, 2, 6, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 0.98
#
# Current board: [6, 2, 5, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 0.97
#
# Current board: [6, 2, 5, 4, 1, 7, 4, 2]
# Conflicts: 4
# Temperature: 0.96
#
# Current board: [6, 2, 5, 4, 1, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.95
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.94
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.94
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.93
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.92
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.91
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.90
#
# Current board: [6, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 6
# Temperature: 0.89
#
# Current board: [0, 2, 5, 4, 7, 1, 4, 2]
# Conflicts: 5
# Temperature: 0.88
#
# Current board: [0, 2, 5, 2, 7, 1, 4, 2]
# Conflicts: 4
# Temperature: 0.87
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 2]
# Conflicts: 4
# Temperature: 0.86
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 2]
# Conflicts: 4
# Temperature: 0.85
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 2]
# Conflicts: 5
# Temperature: 0.85
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.84
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.83
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.82
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.81
#
# Current board: [0, 2, 7, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.80
#
# Current board: [0, 2, 3, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.80
#
# Current board: [0, 2, 3, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.79
#
# Current board: [0, 2, 3, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.78
#
# Current board: [0, 2, 3, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.77
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.76
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.76
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.75
#
# Current board: [0, 2, 5, 1, 7, 1, 4, 6]
# Conflicts: 3
# Temperature: 0.74
#
# Current board: [0, 2, 5, 1, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.73
#
# Current board: [0, 3, 5, 1, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.73
#
# Current board: [0, 3, 5, 1, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.72
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.71
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.71
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.70
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.69
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.68
#
# Current board: [0, 3, 5, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.68
#
# Current board: [0, 3, 0, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.67
#
# Current board: [0, 3, 0, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.66
#
# Current board: [0, 3, 0, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.66
#
# Current board: [0, 3, 0, 2, 7, 1, 2, 6]
# Conflicts: 4
# Temperature: 0.65
#
# Current board: [0, 3, 0, 2, 7, 1, 2, 1]
# Conflicts: 5
# Temperature: 0.64
#
# Current board: [0, 3, 0, 7, 7, 1, 2, 1]
# Conflicts: 5
# Temperature: 0.64
#
# Current board: [0, 3, 0, 7, 7, 1, 2, 1]
# Conflicts: 5
# Temperature: 0.63
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.63
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.62
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.61
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.61
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.60
#
# Current board: [0, 3, 0, 7, 7, 2, 2, 1]
# Conflicts: 4
# Temperature: 0.59
#
# Current board: [0, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.59
#
# Current board: [0, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.58
#
# Current board: [0, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.58
#
# Current board: [1, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.57
#
# Current board: [1, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.57
#
# Current board: [1, 3, 0, 7, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.56
#
# Current board: [1, 3, 0, 5, 7, 2, 4, 1]
# Conflicts: 4
# Temperature: 0.55
#
# Current board: [1, 3, 0, 5, 7, 2, 4, 7]
# Conflicts: 3
# Temperature: 0.55
#
# Current board: [1, 3, 6, 5, 7, 2, 4, 7]
# Conflicts: 3
# Temperature: 0.54
#
# Current board: [1, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.54
#
# Current board: [1, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.53
#
# Current board: [1, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.53
#
# Current board: [1, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.52
#
# Current board: [1, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.52
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.51
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.51
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.50
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.50
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.49
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.49
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.48
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.48
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.47
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.47
#
# Current board: [5, 3, 6, 0, 7, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.46
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.46
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.45
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.45
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.44
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.44
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.44
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.43
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.43
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.42
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.42
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.41
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.41
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.41
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.40
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.40
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.39
#
# Current board: [5, 3, 6, 0, 5, 2, 4, 7]
# Conflicts: 2
# Temperature: 0.39
#
# Current board: [5, 3, 6, 0, 5, 1, 4, 7]
# Conflicts: 1
# Temperature: 0.39
#
# Current board: [5, 3, 6, 0, 5, 1, 4, 7]
# Conflicts: 1
# Temperature: 0.38
#
# Current board: [5, 3, 6, 0, 5, 1, 4, 7]
# Conflicts: 1
# Temperature: 0.38
#
# Current board: [5, 3, 6, 0, 7, 1, 4, 7]
# Conflicts: 1
# Temperature: 0.37
#
# Solution found:
# [5, 3, 6, 0, 7, 1, 4, 2]
