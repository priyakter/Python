# %% [markdown]
# <a href="https://colab.research.google.com/github/priyakter/Python/blob/main/CostFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

actual = np.array([-2, 1, -3, 2, 3, 5, 4, 6, 5, 6, 7])
predicted = np.array([-1, -1, -2, 2, 3, 4, 4, 5, 5, 7, 7])

# %%
MAE = np.mean(np.abs(actual - predicted))
MSE = np.mean((actual - predicted) ** 2)
RMSE = np.sqrt(MSE)
R2 = 1 - (np.sum((actual - predicted) ** 2) / np.sum((actual - np.mean(actual)) ** 2))


print(f"MAE: {MAE}")
print(f"MSE: {MSE}")
print(f"RMSE: {RMSE}")
print(f"R-squared: {R2}")

# %%
MAE = mean_absolute_error(actual, predicted)
MSE = mean_squared_error(actual, predicted)
RMSE= np.sqrt(MSE)
R2 = r2_score(actual, predicted)

print(f"MAE: {MAE}")
print(f"MSE: {MSE}")
print(f"RMSE: {RMSE}")
print(f"R-squared: {R2}")
# Out:
# MAE: 0.6363636363636364
# MSE: 0.8181818181818182
# RMSE: 0.9045340337332909
# R-squared: 0.9173622704507512
