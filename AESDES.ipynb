# %% [markdown]
# <a href="https://colab.research.google.com/github/priyakter/Python/blob/main/AESDES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
import binascii

# AES Encryption Function
def aes_encrypt(plaintext, key):
    cipher = AES.new(key, AES.MODE_ECB)
    ciphertext = cipher.encrypt(pad(plaintext.encode(), AES.block_size))
    return binascii.hexlify(ciphertext).decode()

# AES Decryption Function
def aes_decrypt(ciphertext, key):
    cipher = AES.new(key, AES.MODE_ECB)
    decrypted_text = unpad(cipher.decrypt(binascii.unhexlify(ciphertext)), AES.block_size)
    return decrypted_text.decode()

# Example Usage
key = input("Enter a 16-byte key: ").encode()
plaintext = input("Enter plaintext: ")

ciphertext = aes_encrypt(plaintext, key)
decrypted_text = aes_decrypt(ciphertext, key)

print(f"Ciphertext: {ciphertext}")
print(f"Decrypted: {decrypted_text}")
# Out:
# Enter a 16-byte key: 9857363826273473
# Enter plaintext: 9876543211234567
# Ciphertext: cb316050151be9deb90fdb98e995b621a194a537c75a6e9f209c07b191eda67e
# Decrypted: 9876543211234567

# %%
# Install dependencies for Google Colab
# !pip install pycryptodome

from Crypto.Cipher import DES
from Crypto.Util.Padding import pad, unpad
import binascii

# DES Encryption Function
def des_encrypt(plaintext, key):
    cipher = DES.new(key, DES.MODE_ECB)
    ciphertext = cipher.encrypt(pad(plaintext.encode(), DES.block_size))
    return binascii.hexlify(ciphertext).decode()

# DES Decryption Function
def des_decrypt(ciphertext, key):
    cipher = DES.new(key, DES.MODE_ECB)
    decrypted_text = unpad(cipher.decrypt(binascii.unhexlify(ciphertext)), DES.block_size)
    return decrypted_text.decode()

# Example Usage
key = input("Enter an 8-byte key: ").encode()
plaintext = input("Enter plaintext: ")

ciphertext = des_encrypt(plaintext, key)
decrypted_text = des_decrypt(ciphertext, key)

print(f"Ciphertext: {ciphertext}")
print(f"Decrypted: {decrypted_text}")
# Out:
# ...
# Enter an 8-byte key: 23456784
# Enter plaintext: 12345678901234567890
# Ciphertext: 262f29009a5a93039483b52954b96d49ca08ab64e46c3a0a
# Decrypted: 12345678901234567890

# %%
# !pip install pycryptodome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.0 MB/s eta 0:00:00
# ...
