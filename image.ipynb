# %% [markdown]
# <a href="https://colab.research.google.com/github/priyakter/Python/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image= cv2.imread('/001.jpeg',1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
image.shape
# Out:
# (168, 300, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
resize image= cv2.resize(image,[500,500],interpolation=cv2.INTER_NEAREST)
cropped_image=image([10:100,50:200])
cv2.imshow(cropped_image)
resize image= cv2.resize(image,[500,500],interpolation=cv2.INTER_LINEAR)

rotate_image = cv2.rotate(image,cv2.ROTATE_90_CLOCKWISE)

cv2.imshow(cricle_image)
# Out:
# numpy.ndarray

# %%
from google.colab import drive
drive.mount('/content/drive')
